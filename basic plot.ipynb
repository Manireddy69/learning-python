# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [79,89,99]
y = [69,89,100]
plt.plot(x,y,label = "10x", linewidth = 1,marker = '*',markersize = 5,linestyle = '--')

plt.title("First Graph")
plt.xlabel("X Axis")
plt.ylabel("Y label")

plt.xticks([60,70,80,90,100])
plt.yticks([60,70,80,90,100])

plt.legend()
plt.show()
